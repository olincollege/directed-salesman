# %%
import brute_force
import branch_and_bound
import utils
import alg_test
import math
import networkx as nx
import held_karp
import matplotlib.pyplot as plt
import copy
import numpy as np
import nearest_neighbor
import held_karp

# %%
sizes = list(range(19))
sizes.remove(0)
sizes.remove(1)
sizes.remove(2)
num_runs = 30
alg = nearest_neighbor.tsp_nearest_neighbor

times_circle, corr_circle = alg_test.run_multiple_on_range_with_correct(utils.circle_graph, alg, sizes, 1)
times_grid, corr_grid = alg_test.run_multiple_on_range_with_correct(utils.rectangle_graph, alg, sizes, 1)
times_rando, corr_rando = alg_test.run_multiple_on_range_with_correct(utils.random_graph, alg, sizes, num_runs)
times_barb_comp, corr_barb_comp = alg_test.run_multiple_on_range_with_correct(utils.complete_barbell, alg, sizes, num_runs)


"""
times_circle = alg_test.run_multiple_on_range_no_correct(utils.circle_graph, alg, sizes, 1)
times_grid = alg_test.run_multiple_on_range_no_correct(utils.rectangle_graph, alg, sizes, 1)
times_rando = alg_test.run_multiple_on_range_no_correct(utils.random_graph, alg, sizes, num_runs)
times_barb_comp = alg_test.run_multiple_on_range_no_correct(utils.complete_barbell, alg, sizes, num_runs)
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 10
#       8 times_circle, corr_circle = alg_test.run_multiple_on_range_with_correct(utils.circle_graph, alg, sizes, 1)
#       9 times_grid, corr_grid = alg_test.run_multiple_on_range_with_correct(utils.rectangle_graph, alg, sizes, 1)
# ---> 10 times_rando, corr_rando = alg_test.run_multiple_on_range_with_correct(utils.random_graph, alg, sizes, num_runs)
#      11 times_barb_comp, corr_barb_comp = alg_test.run_multiple_on_range_with_correct(utils.complete_barbell, alg, sizes, num_runs)
#      14 """
#      15 times_circle = alg_test.run_multiple_on_range_no_correct(utils.circle_graph, alg, sizes, 1)
#      16 times_grid = alg_test.run_multiple_on_range_no_correct(utils.rectangle_graph, alg, sizes, 1)
#      17 times_rando = alg_test.run_multiple_on_range_no_correct(utils.random_graph, alg, sizes, num_runs)
#      18 times_barb_comp = alg_test.run_multiple_on_range_no_correct(utils.complete_barbell, alg, sizes, num_runs)
#      19 """
#
# File ~/Documents/Olin Classwork/Junior Year/Fall/Discrete/Final/directed-salesman/alg_test.py:194, in run_multiple_on_range_with_correct(graph_making_alg, algorithm, sizes, num_runs)
#     192 corrs = []
#     193 for run in range(num_runs):
# --> 194     taken, corr = run_on_range_with_correct(graph_making_alg, algorithm, [size])
#     195     taken = taken[0]
#     196     corr = corr[0]
#
# File ~/Documents/Olin Classwork/Junior Year/Fall/Discrete/Final/directed-salesman/alg_test.py:161, in run_on_range_with_correct(graph_making_alg, algorithm, sizes)
#     159 else:
#     160     graph = graph_making_alg(size)
# --> 161     shortest_length = get_min_length_held_karp(graph)
#     162 taken_time, correctness = run_on_determined_graph(graph, algorithm, shortest_length)
#     163 times.append(taken_time)
#
# File ~/Documents/Olin Classwork/Junior Year/Fall/Discrete/Final/directed-salesman/alg_test.py:99, in get_min_length_held_karp(graph)
#      89 def get_min_length_held_karp(graph: nx.Graph) -> float:
#      90     """
#      91     Gets the length of the shortest path through the given graph that hits every node.
#      92
#    (...)
#      97     :return: a float representing the length of the shortest path through the given graph
#      98     """
# ---> 99     best_length, best_path = held_karp.held_karp(graph)
#     100     return best_length
#
# File ~/Documents/Olin Classwork/Junior Year/Fall/Discrete/Final/directed-salesman/held_karp.py:32, in held_karp(graph)
#      30 if m == k:
#      31     continue
# ---> 32 dist, path = cache[(subset.difference(make_bitset(1 << k)), m)]
#      33 act_dist = dist + graph[m][k]['weight']
#      34 if shortest[0] == -1 or act_dist < shortest[0]:
#
# File ~/Documents/Olin Classwork/Junior Year/Fall/Discrete/Final/directed-salesman/bitset.py:173, in BitSet.difference(self, *others)
#     166 def difference(self, *others: 'BitSet') -> 'BitSet':
#     167     """
#     168     Calculates the difference between two or more sets
#     169
#     170     :param others: the list of BitSets containing elements to remove
#     171     :return: a BitSet representing the difference of this set with the sets in others
#     172     """
# --> 173     value = self.value
#     174     for other in others:
#     175         value = value & other.complement_value()
#
# KeyboardInterrupt:

# %%
plt.plot(sizes, times_circle, label = "circle")
#plt.plot(sizes, times_grid, label = "grid")
plt.plot(sizes, times_rando, label = "random")
plt.plot(sizes, times_barb_comp, label = "complete barbell")
plt.xlabel("Number of Nodes in Graph")
plt.ylabel("Average Time to Run One Solution (s)")
plt.title("Branch and Bound")

plt.legend()
plt.show()

# %%
plt.plot(sizes, corr_circle, label = "circle")
plt.plot(sizes, corr_grid, label = "grid")
plt.plot(sizes, corr_rando, label = "random")
plt.plot(sizes, corr_barb_comp, label = "complete barbell")
plt.xlabel("Number of Nodes in Graph")
plt.ylabel("Average Correctness of Solution")
plt.title("Branch and Bound")

plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
arr_init = [[np.inf, 3, 1, 5, 8],[3, np.inf, 6, 7, 9], [1,6,np.inf,4,2],[5,7,4,np.inf,3],[8,9,2,3,np.inf]]
arr_np = np.matrix(arr_init)
print(arr_np)
graph = utils.barbell_graph(2)
# Out:
# [[inf  3.  1.  5.  8.]
#  [ 3. inf  6.  7.  9.]
#  [ 1.  6. inf  4.  2.]
#  [ 5.  7.  4. inf  3.]
#  [ 8.  9.  2.  3. inf]]

# %%
sizes = list(range(15))
sizes.remove(0)
sizes.remove(1)
sizes.remove(2)
num_runs = 1
alg = branch_and_bound.branch_and_bound
"""
times_circle, corr_circle = alg_test.run_multiple_on_range_with_correct(utils.circle_graph, alg, sizes, 1)
times_grid, corr_grid = alg_test.run_multiple_on_range_with_correct(utils.rectangle_graph, alg, sizes, 1)
times_rando, corr_rando = alg_test.run_multiple_on_range_with_correct(utils.random_graph, alg, sizes, num_runs)
times_barb_comp, corr_barb_comp = alg_test.run_multiple_on_range_with_correct(utils.complete_barbell, alg, sizes, num_runs)


"""
times_bip = alg_test.run_multiple_on_range_no_correct(utils.bipartite_graph, alg, sizes, 1)
plt.plot(sizes, times_bip, label = "random")

# %%
sizes = list(range(19))
sizes.remove(0)
sizes.remove(1)
sizes.remove(2)
num_runs = 30

#times_held_karp, corr_held_karp = alg_test.run_multiple_on_range_with_correct(utils.random_graph, held_karp.held_karp, sizes, 1)
#print("held karp done")
#times_brute_force, corr_brute_force = alg_test.run_multiple_on_range_with_correct(utils.random_graph, brute_force.brute_force, sizes, 1)
#print("brute force done")

times_nearest_neighbor, corr_nearest_neighbor = alg_test.run_multiple_on_range_with_correct(utils.random_graph, nearest_neighbor.tsp_nearest_neighbor, sizes, num_runs)
print("nearest neighbor done")

times_branch_and_bound, corr_branch_and_bound = alg_test.run_multiple_on_range_with_correct(utils.random_graph, branch_and_bound.branch_and_bound, sizes, num_runs)
# Out:
# nearest neighbor done

# %%
#plt.plot(sizes, times_held_karp, label = "Held Karp")
#plt.plot(sizes, times_brute_force, label = "Brute Force")
plt.plot(sizes, times_nearest_neighbor, label = "Nearest Neighbor")
plt.plot(sizes, times_branch_and_bound, label = "Branch and Bound")
plt.xlabel("Number of Nodes in Graph")
plt.ylabel("Average Time to Run One Solution (s)")
plt.title("Algorithm Comparison")

plt.legend()
plt.show()

# %%
#plt.plot(sizes, corr_held_karp, label = "Held Karp")
#plt.plot(sizes, corr_brute_force, label = "Brute Force")
plt.plot(sizes, corr_nearest_neighbor, label = "Nearest Neighbor")
plt.plot(sizes, corr_branch_and_bound, label = "Branch and Bound")
plt.xlabel("Number of Nodes in Graph")
plt.ylabel("Average Correctness")
plt.title("Algorithm Comparison")

plt.legend()
plt.show()
